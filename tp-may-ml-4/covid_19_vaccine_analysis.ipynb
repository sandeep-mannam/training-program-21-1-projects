# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-b0f35182-08d8-4b8d-b647-5744a45d2a9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0f35182-08d8-4b8d-b647-5744a45d2a9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_vaccinations.csv to country_vaccinations.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("country_vaccinations.csv")
data.head()
# Out:
#        country iso_code  ...                source_name            source_website
# 0  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 1  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 2  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 3  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 4  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
#
# [5 rows x 15 columns]

# %%
data.describe()
# Out:
#        total_vaccinations  ...  daily_vaccinations_per_million
# count        1.194600e+04  ...                    20705.000000
# mean         6.884554e+06  ...                     3222.074813
# std          3.065135e+07  ...                     8313.204950
# min          0.000000e+00  ...                        0.000000
# 25%          7.797450e+04  ...                      359.000000
# 50%          5.557355e+05  ...                     1615.000000
# 75%          2.579226e+06  ...                     4459.000000
# max          6.029910e+08  ...                  1000000.000000
#
# [8 rows x 9 columns]

# %%
pd.to_datetime(data.date)
data.country.value_counts()
# Out:
# Norway                             177
# Canada                             166
# China                              165
# Russia                             165
# Denmark                            162
#                                   ...
# Tuvalu                               1
# Cook Islands                         1
# Central African Republic             1
# Guinea-Bissau                        1
# Bonaire Sint Eustatius and Saba      1
# Name: country, Length: 214, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Oxford/AstraZeneca                                                                    3670
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                         2985
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1630
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   1602
# Moderna, Pfizer/BioNTech                                                              1253
# Pfizer/BioNTech                                                                       1214
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                          1028
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  905
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      904
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                 403
# Oxford/AstraZeneca, Sputnik V                                                          357
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                329
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       310
# Sinopharm/Beijing                                                                      290
# Sinopharm/Beijing, Sputnik V                                                           270
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac                                         250
# Pfizer/BioNTech, Sinopharm/Beijing                                                     246
# Oxford/AstraZeneca, Sinovac                                                            235
# Pfizer/BioNTech, Sinovac                                                               232
# Sputnik V                                                                              212
# Oxford/AstraZeneca, Sinovac, Sputnik V                                                 186
# CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                   165
# EpiVacCorona, Sputnik V                                                                165
# Johnson&Johnson, Moderna, Pfizer/BioNTech                                              160
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                       155
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V             152
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     144
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing                                         144
# Covaxin, Oxford/AstraZeneca                                                            135
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V                              122
# QazVac, Sinopharm/HayatVax, Sputnik V                                                  117
# CanSino, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V                     115
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                              106
# Johnson&Johnson, Pfizer/BioNTech                                                        99
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V                      95
# Moderna, Oxford/AstraZeneca                                                             92
# Pfizer/BioNTech, Sputnik V                                                              90
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Sputnik V                                 87
# Pfizer/BioNTech, Sinovac, Sputnik V                                                     77
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                         61
# Oxford/AstraZeneca, RBD-Dimer, Sputnik V                                                56
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                               35
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                24
# Abdala, Soberana02                                                                      15
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                           1
# Name: vaccines, dtype: int64

# %%
df = data[["vaccines","country"]]
df.head()
# Out:
#                                             vaccines      country
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 2  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan

# %%
dict_={}
for i in df.vaccines.unique():
  dict_[i] = [df["country"][j] for j in df[df["vaccines"]==i].index]
vaccines = {}
for key,value in dict_.items():
  vaccines[key] = set(value)
for i, j in vaccines.items():
  print(f"{i}:>>{j}")
# Out:
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Afghanistan', 'Maldives', 'Peru', 'Iraq'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Albania', 'Philippines', 'Bosnia and Herzegovina'}
# Sputnik V:>>{'Guinea', 'Algeria', 'Syria', 'Venezuela'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Cayman Islands', 'Jersey', 'Andorra', 'Australia', 'Slovenia', 'South Korea', 'Costa Rica', 'Sweden', 'Saudi Arabia', 'Cape Verde', 'Panama', 'Oman', 'Isle of Man'}
# Oxford/AstraZeneca:>>{'Montserrat', 'Sierra Leone', 'Trinidad and Tobago', 'Gambia', 'Bhutan', 'Brunei', 'Kosovo', 'Vietnam', 'Taiwan', 'Botswana', 'Anguilla', 'Saint Kitts and Nevis', 'Falkland Islands', 'Pitcairn', 'Sao Tome and Principe', 'Fiji', 'Wallis and Futuna', 'Cook Islands', 'Myanmar', 'Bahamas', 'New Caledonia', 'Democratic Republic of Congo', 'Madagascar', 'Antigua and Barbuda', 'Grenada', 'Yemen', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Samoa', 'British Virgin Islands', 'Bangladesh', 'Uganda', 'Malawi', 'Georgia', 'Togo', 'Tonga', 'Nauru', 'Jamaica', "Cote d'Ivoire", 'Timor', 'Eswatini', 'Mali', 'Angola', 'Barbados', 'Liberia', 'Solomon Islands', 'Nigeria', 'Ethiopia', 'Saint Helena', 'Dominica', 'Suriname', 'Lesotho', 'Tuvalu', 'French Polynesia', 'South Sudan', 'Tajikistan'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Argentina', 'Sri Lanka', 'Djibouti'}
# Oxford/AstraZeneca, Sinovac, Sputnik V:>>{'Armenia', 'Azerbaijan'}
# Pfizer/BioNTech:>>{'Japan', 'New Zealand', 'Slovakia', 'Greenland', 'Bermuda', 'Turks and Caicos Islands', 'Aruba', 'Kuwait', 'Monaco', 'Gibraltar'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Iceland', 'Belgium', 'Romania', 'Cyprus', 'Czechia', 'Ireland', 'Bulgaria', 'Latvia', 'Spain', 'Germany', 'Greece', 'Estonia', 'Malta', 'Austria', 'Lithuania', 'Netherlands', 'Portugal', 'Italy', 'Poland', 'France'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Bolivia', 'Moldova', 'Serbia', 'Mongolia', 'Lebanon', 'North Macedonia', 'Bahrain', 'Montenegro'}
# Sinopharm/Beijing, Sputnik V:>>{'Laos', 'Belarus', 'Kyrgyzstan'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Morocco', 'Seychelles', 'Niger', 'Belize', 'Papua New Guinea', 'Nepal', 'Senegal', 'Cameroon', 'Namibia', 'Zambia', 'Mozambique', 'Guinea-Bissau'}
# Oxford/AstraZeneca, Sinovac:>>{'Benin', 'Indonesia', 'Thailand'}
# Moderna, Pfizer/BioNTech:>>{'Bonaire Sint Eustatius and Saba', 'Norway', 'Faeroe Islands', 'Israel', 'Singapore', 'Curacao', 'Qatar', 'Switzerland', 'Denmark', 'Liechtenstein'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Colombia', 'Ukraine', 'Northern Cyprus', 'Uruguay', 'Brazil', 'Chile', 'El Salvador', 'Malaysia', 'Ecuador'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Somalia', 'Cambodia', 'Dominican Republic'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Canada', 'Sint Maarten (Dutch part)', 'Scotland', 'United Kingdom', 'Northern Ireland', 'Croatia', 'England', 'Rwanda', 'Palestine', 'Finland', 'Wales', 'Guernsey', 'Luxembourg'}
# Covaxin, Oxford/AstraZeneca:>>{'Central African Republic', 'India'}
# CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac:>>{'China'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Comoros', 'Mauritius'}
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Congo'}
# Abdala, Soberana02:>>{'Cuba'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Egypt'}
# Sinopharm/Beijing:>>{'Gabon', 'Zimbabwe', 'Equatorial Guinea', 'Mauritania'}
# Oxford/AstraZeneca, Sputnik V:>>{'Kenya', 'Ghana', 'Nicaragua', 'Guyana'}
# Moderna, Oxford/AstraZeneca:>>{'Guatemala'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Sputnik V:>>{'Honduras'}
# Pfizer/BioNTech, Sinovac:>>{'Turkey', 'Hong Kong'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Iran'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Macao', 'Jordan'}
# QazVac, Sinopharm/HayatVax, Sputnik V:>>{'Kazakhstan'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Libya'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# CanSino, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Pakistan'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Paraguay'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Johnson&Johnson, Pfizer/BioNTech:>>{'South Africa'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Sudan'}
# Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Tunisia'}
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Turkmenistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'United Arab Emirates'}
# Johnson&Johnson, Moderna, Pfizer/BioNTech:>>{'United States'}
# Oxford/AstraZeneca, RBD-Dimer, Sputnik V:>>{'Uzbekistan'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f45f729-125c-40c4-8547-6aa59fa35aa9" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f45f729-125c-40c4-8547-6aa59fa35aa9")) {
#                     Plotly.newPlot(
#                         '3f45f729-125c-40c4-8547-6aa59fa35aa9',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "iso_code=%{location}<br>vaccines=%{z}", "locations": ["AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA",  ...
